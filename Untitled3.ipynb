# %%
from arcgis.gis import GIS

# %%
gis = GIS()

# %%
gis.map('logan utah')
# Out:
# MapView(layout=Layout(height='400px', width='100%'))
# <div class="map-static-img-preview-e6a0a5fe-a058-42a0-b27f-0d5073d54315"><img src=""></img></div>

# %%
import pandas as pd

# %%
df = pd.read_csv('../UT20.csv', parse_dates=['Date_Time'], index_col='Date_Time', skiprows=[0,1,2,3,4,5,7])
df.head()
# Out:
#                           Station_ID  air_temp_set_1
# Date_Time
# 2016-06-01 00:00:00+00:00       UT20           74.07
# 2016-06-01 00:10:00+00:00       UT20           74.25
# 2016-06-01 00:20:00+00:00       UT20           74.30
# 2016-06-01 00:30:00+00:00       UT20           74.35
# 2016-06-01 00:40:00+00:00       UT20           74.43

# %%
df.loc['2016-06-01':'2016-06-15'].plot(figsize=(15, 5), color='red')
